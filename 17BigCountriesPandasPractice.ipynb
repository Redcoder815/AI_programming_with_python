# %% [markdown]
# <a href="https://colab.research.google.com/github/Redcoder815/AI_programming_with_python/blob/main/17BigCountriesPandasPractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

def big_countries(world):
  ans = world.loc[(world['area'] >= 3000000) | (world['population'] >= 2500000), ['name', 'population', 'area']]
  return ans
