# %% [markdown]
# <a href="https://colab.research.google.com/github/Redcoder815/AI_programming_with_python/blob/main/28MidTermExam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Registered email: artificial815@gmail.com

# %%
import numpy as np
import pandas as pd

np.random.seed(24)

num_employees = 50  # you can increase this if needed

# Employee data
emp_ids = np.arange(101, 101 + num_employees)
emp_ages = np.random.randint(20, 55, num_employees)
emp_income = np.random.randint(35000, 95000, num_employees)

# Fixed set of roles (repetition allowed)
roles_list = [
    "HR Manager",
    "Software Developer",
    "Accountant",
    "Marketing Executive",
    "Sales Executive",
    "Backend Developer",
    "HR Executive",
    "Financial Analyst",
    "Digital Marketer",
    "Operations Manager"
]

emp_roles = np.random.choice(roles_list, num_employees)

# Create DataFrame
data = pd.DataFrame({
    "emp_id": emp_ids,
    "emp_age": emp_ages,
    "emp_salary": emp_income,
    "role": emp_roles
})

# Save dataset
data.to_csv("staff_data.csv", index=False)

# %% [markdown]
# Q1

# %%
df = pd.read_csv("/content/staff_data.csv")

employ_age = np.array(df["emp_age"])
employ_salary = np.array(df["emp_salary"])
print(employ_age)
print(employ_salary)
print(f"employ_age data type {employ_age.dtype} and emp_salary data type {employ_salary.dtype}")

print(f"employ_age dimension {employ_age.ndim} and emp_salary dimension {employ_salary.ndim}")

print(f"employ_age shape {employ_age.shape} and emp_salary shape {employ_salary.shape}")

print(f"employ_age total number of elements {employ_age.size} and emp_salary total number of elements {employ_salary.size}")
# Out:
# [54 23 20 43 37 37 21 35 24 38 31 35 29 38 27 45 51 48 20 32 51 53 21 26
#  53 37 26 21 45 30 20 47 53 53 23 24 21 30 27 25 39 20 47 41 22 52 42 54
#  31 50]
# [51725 38495 35452 82295 72187 58915 76159 92864 76155 90494 68641 48079
#  56879 83682 94722 91041 48899 68744 63187 74146 75641 47678 76760 78354
#  60584 79898 59682 71888 51086 73700 82550 71447 76100 72269 73314 87428
#  94427 84188 52013 63326 44396 59500 55523 58602 90794 41061 82331 73048
#  59727 50398]
# employ_age data type int64 and emp_salary data type int64
# employ_age dimension 1 and emp_salary dimension 1
# employ_age shape (50,) and emp_salary shape (50,)
# employ_age total number of elements 50 and emp_salary total number of elements 50

# %% [markdown]
# Q2

# %%
maximum_salary = np.max(employ_salary)
minimum_salary = np.min(employ_salary)
average_salary = np.mean(employ_salary)
average_age = np.mean(employ_age)
print(f"maximum salary {maximum_salary}")
print(f"minimum salary {minimum_salary}")
print(f"average salary {average_salary}")
print(f"average age {average_age}")
# Out:
# maximum salary 94722
# minimum salary 35452
# average salary 68409.48
# average age 35.44

# %% [markdown]
# Q3

# %%
age_filter = employ_age[(employ_age >= 25) & (employ_age <= 40)]
print(age_filter)
salary_filter = employ_salary[employ_salary > 50000]
print(salary_filter)
print(f"Total satisfy this conditon {age_filter.size + salary_filter.size}")
# Out:
# [37 37 35 38 31 35 29 38 27 32 26 37 26 30 30 27 25 39 31]
# [51725 82295 72187 58915 76159 92864 76155 90494 68641 56879 83682 94722
#  91041 68744 63187 74146 75641 76760 78354 60584 79898 59682 71888 51086
#  73700 82550 71447 76100 72269 73314 87428 94427 84188 52013 63326 59500
#  55523 58602 90794 82331 73048 59727 50398]
# Total satisfy this conditon 62

# %% [markdown]
# Q4

# %%
updated_age = np.where(employ_age >= average_age, employ_age + 2, employ_age + 4)
print(employ_age)
print(updated_age)
print(f"Average age for condition {average_age}")
# Out:
# [54 23 20 43 37 37 21 35 24 38 31 35 29 38 27 45 51 48 20 32 51 53 21 26
#  53 37 26 21 45 30 20 47 53 53 23 24 21 30 27 25 39 20 47 41 22 52 42 54
#  31 50]
# [56 27 24 45 39 39 25 39 28 40 35 39 33 40 31 47 53 50 24 36 53 55 25 30
#  55 39 30 25 47 34 24 49 55 55 27 28 25 34 31 29 41 24 49 43 26 54 44 56
#  35 52]
# Average age for condition 35.44

# %% [markdown]
# Q5

# %%
# # print(df)
# role_list = np.array(df["role"])
# indices_of_role = np.where((role_list == "Software Developer") | (role_list == "Backend Developer") | (role_list == "Digital Marketer"))
# # print(indices_of_role)

# employ_salary = employ_salary.astype(float)

# # print(employ_salary)
# old_total_salary = np.sum(employ_salary)
# # for i in indices_of_role:
# #   employ_salary[i] *= 1.08

# employ_salary[indices_of_role] *= 1.08
# new_total_salary = np.sum(employ_salary)
# increase_of_salary = new_total_salary - old_total_salary

# print(f"Old total salary expenses {old_total_salary}")
# print(f"New total salary expenses {new_total_salary}")
# print(f"Total difference {increase_of_salary}")
# print(employ_salary)
# print(df)
#------------------------------------------------------------
# tech_roles_array = ["Software Developer", "Backend Developer", "Digital Marketer"]
# print(employ_salary)
# previous_total_salary = np.sum(employ_salary)
# new_total_salary_expense = 0.00
# for i, (job, salary) in enumerate(zip(role_list, employ_salary)):
#   if job in tech_roles_array:
#     new_total_salary_expense = new_total_salary_expense + (salary * 0.08)
#     employ_salary[i] = salary + (salary * 0.08)
#     # employ_salary[i] = employ_salary[i] + (employ_salary[i] * 0.08)

# print(f"Old total {previous_total_salary}")
# print(f"new total {np.sum(employ_salary):.2f}")
# print(f"overall increase in expense after the raise {((np.sum(employ_salary)) - previous_total_salary):.2f}")
#-------------------------------------------
tech_roles_array = ["Software Developer", "Backend Developer", "Digital Marketer"]

role_list = np.array(df["role"])
# print(role_list)

employ_salary = employ_salary.astype(float)
updated_salary = np.where(np.isin(role_list, tech_roles_array), employ_salary * 1.08, employ_salary)
old_total_salary = np.sum(employ_salary)
new_total_salary = np.sum(updated_salary)
increase_of_salary = new_total_salary - old_total_salary

print(f"Old total salary expenses {old_total_salary}")
print(f"New total salary expenses {new_total_salary}")
print(f"Total difference {increase_of_salary}")

# print(employ_salary)
# print(updated_salary)
# Out:
# Old total salary expenses 3420474.0
# New total salary expenses 3524808.08
# Total difference 104334.08000000007

# %% [markdown]
# Q6

# %%
df = pd.read_csv("/content/staff_data.csv")
print(df.head(3))
print(df.info())
print(df.describe())
# Out:
#    emp_id  emp_age  emp_salary                role
# 0     101       54       51725          HR Manager
# 1     102       23       38495          Accountant
# 2     103       20       35452  Operations Manager
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   emp_id      50 non-null     int64
#  1   emp_age     50 non-null     int64
#  2   emp_salary  50 non-null     int64
#  3   role        50 non-null     object
# dtypes: int64(3), object(1)
# memory usage: 1.7+ KB
# None
#           emp_id    emp_age    emp_salary
# count   50.00000  50.000000     50.000000
# mean   125.50000  35.440000  68409.480000
# std     14.57738  11.768446  15727.122334
# min    101.00000  20.000000  35452.000000
# 25%    113.25000  24.250000  57309.750000
# 50%    125.50000  35.000000  72037.500000
# 75%    137.75000  46.500000  79512.000000
# ...

# %% [markdown]
# Q7

# %%
# print(df)
filter_data = df[["emp_id", "emp_age", "role"]]
filter_by_age = filter_data.loc[(df['emp_age'] >= 25) & (df['emp_age'] <= 40)]
sort_by_emp_id = filter_by_age.sort_values(["emp_id"])
sort_by_emp_id.tail(3)
# Out:
#     emp_id  emp_age                 role
# 39     140       25      Sales Executive
# 40     141       39  Marketing Executive
# 48     149       31     Digital Marketer

# %% [markdown]
# Q8

# %%
filter_hr_role = df.loc[df["role"].str.contains("HR")]
print(filter_hr_role)
# print(filter_hr_role.shape)
print(f"Total number of hr employee {filter_hr_role.shape[0]}")
# Out:
#     emp_id  emp_age  emp_salary          role
# 0      101       54       51725    HR Manager
# 5      106       37       58915    HR Manager
# 9      110       38       90494  HR Executive
# 24     125       53       60584  HR Executive
# 27     128       21       71888  HR Executive
# 38     139       27       52013    HR Manager
# 42     143       47       55523  HR Executive
# 44     145       22       90794  HR Executive
# 45     146       52       41061    HR Manager
# Total number of hr employee 9

# %% [markdown]
# Q9

# %%
sort_by_emp_age_and_salary = df.sort_values(["emp_age", "emp_salary"], ascending=[1,0])

data_id__role_salary = sort_by_emp_age_and_salary[["emp_id", "role", "emp_salary"]]
# print(sort_by_emp_age)
# print(sort_by_emp_salary)
print("Top five employess ")
print(data_id__role_salary.head(5))
# Out:
# Top five employess
#     emp_id                role  emp_salary
# 30     131     Sales Executive       82550
# 18     119  Software Developer       63187
# 41     142    Digital Marketer       59500
# 2      103  Operations Manager       35452
# 36     137     Sales Executive       94427

# %% [markdown]
# Q10

# %%
df["new_salary"] = df["emp_salary"]
df.loc[(df["role"] == "Software Developer") | (df["role"] == "Backend Developer"), "new_salary"] *= 1.12
df.loc[(df["role"] != "Software Developer") & (df["role"] != "Backend Developer"), "new_salary"] *= 1.05

df["previous_salary"] = df["emp_salary"]
df["increase_of_salary"] = df["new_salary"] - df["previous_salary"]
df_data = df[["role", "previous_salary", "new_salary", "increase_of_salary"]]
print(df_data)
# Out:
#                    role  previous_salary  new_salary  increase_of_salary
# 0            HR Manager            51725    54311.25             2586.25
# 1            Accountant            38495    40419.75             1924.75
# 2    Operations Manager            35452    37224.60             1772.60
# 3      Digital Marketer            82295    86409.75             4114.75
# 4     Backend Developer            72187    80849.44             8662.44
# 5            HR Manager            58915    61860.75             2945.75
# 6     Backend Developer            76159    85298.08             9139.08
# 7       Sales Executive            92864    97507.20             4643.20
# 8       Sales Executive            76155    79962.75             3807.75
# 9          HR Executive            90494    95018.70             4524.70
# 10    Backend Developer            68641    76877.92             8236.92
# 11  Marketing Executive            48079    50482.95             2403.95
# ...
