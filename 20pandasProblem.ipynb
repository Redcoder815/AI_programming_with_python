# %% [markdown]
# <a href="https://colab.research.google.com/github/Redcoder815/AI_programming_with_python/blob/main/20pandasProblem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
def drop_duplicates_emails(person):
  person.sort_values('id', inplace = True)
  person.drop_duplicates(subset = 'email', inplace = True)

# %%
def count_salary_categories(accounts):
  low_salary = (accounts['income'] < 20000).sum()
  average_salary = ((accounts['income'] >= 20000) & (accounts['income'] <= 50000)).sum()
  high_salary = (accounts['income'] > 50000).sum()

  data = [('Low Salary', low_salary), ('Average Salary', average_salary), ('High Salary', high_salary)]

  df = pd.DataFrame(data, columns = ['category', 'accounts_count'])

  return df
